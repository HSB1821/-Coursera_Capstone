# %% [markdown]
# 1.Web scraping.

# %%
import pandas
import requests
from bs4 import BeautifulSoup
import sys

def get_tables(url,find_string={ "class" : "wikitable sortable" }):
    data=requests.get(url).text
    soup = BeautifulSoup(data,"html5lib")
    [x.extract() for x in soup.findAll('span',{"style":"display:none"})]
    tables = soup.findAll("table",find_string)
    return tables

def fetch_table(table):
    theads=[]
    for tx in table.findAll('th'):
        theads.append(tx.text)
    data=[]
    tbody=table.find('tbody')
    for rows in tbody.findAll('tr'):
        row={}
        i=0
        for cell in rows.findAll('td'):
            
            row[theads[i]]=cell.text
            
           # print(row)
            i+=1
        if len(row)!=0:
            data.append(row)
        
    return data
            
def get_all_tables(url,mode='',find_string={ "class" : "wikitable sortable" }):
    tables=get_tables(url,find_string)
    data=[]
    dataframe=[]
    for table in tables:
        data.append(fetch_table(table))
    if mode=='dict-array':
        return data
    elif mode=='dataframe':
        for d in data:
            dataframe.append(pandas.DataFrame(d))
        return dataframe
    else:
        return data


if __name__=="__main__":
   # if len(sys.argv)<=1:
    url="https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
    #else:
     #   url=sys.argv[1]
    for df in get_all_tables(url,mode='dataframe'):
        print ('================================================================')
        print (df.head())
        print (' ')
        print (' ')
# Out:
# ...
#             Borough     Neighbourhood\n Postcode
# 0      Not assigned      Not assigned\n      M1A
# 1      Not assigned      Not assigned\n      M2A
# 2        North York         Parkwoods\n      M3A
# 3        North York  Victoria Village\n      M4A
# 4  Downtown Toronto      Harbourfront\n      M5A

# %% [markdown]
# 2.Removing Not assigned.

# %%
dataframe=[]
for i  in df['Neighbourhood\n']:
   # 
    i=i.rstrip()
    dataframe.append(i)
    
df['Neighbourhood']=dataframe  
df = df[[ 'Postcode','Borough', 'Neighbourhood']]
df=df[df.Borough!='Not assigned']

# %%
for k in range(210):
 
   
    
    if(   df.iat[k,2]=='Not assigned'):
        df.iat[k,2]=df.iat[k,1]

# %%
d=df['Neighbourhood'].groupby(df['Postcode'],).agg(lambda x: ','.join(x.values)).reset_index()

# %%
d=pandas.DataFrame(d)

# %%
df.nunique()
# Out:
# Postcode         103
# Borough           11
# Neighbourhood    207
# dtype: int64

# %%
##df['Neighbourhood']=d

# %%
#for i in range(103):
 #   df.iat[i,2]=d['Neighbourhood'][i]

# %%
df.reset_index()
# Out:
#      index Postcode           Borough  \
# 0        2      M3A        North York
# 1        3      M4A        North York
# 2        4      M5A  Downtown Toronto
# 3        5      M6A        North York
# 4        6      M6A        North York
# 5        7      M7A      Queen's Park
# 6        9      M9A      Queen's Park
# 7       10      M1B       Scarborough
# 8       11      M1B       Scarborough
# 9       13      M3B        North York
# 10      14      M4B         East York
# 11      15      M4B         East York
# 12      16      M5B  Downtown Toronto
# 13      17      M5B  Downtown Toronto
# 14      18      M6B        North York
# 15      21      M9B         Etobicoke
# 16      22      M9B         Etobicoke
# 17      23      M9B         Etobicoke
# 18      24      M9B         Etobicoke
# 19      25      M9B         Etobicoke
# 20      26      M1C       Scarborough
# 21      27      M1C       Scarborough
# 22      28      M1C       Scarborough
# ...

# %%
dd=df['Borough'].groupby(df['Postcode'])
dd=pandas.DataFrame(dd)

# %%
dr=[]
#dr=pandas.DataFrame(dr)

# %%
for i in range(103):
   # print(i)
    for j in range(209): 
        if(d.iat[i,0]==df.iat[j,0]):
            #print(d.iat[i,0],df.iat[j,0])
            dr[i]=df.iat[j,1]
            #print(dr)
           # print(i,j)
            break

# %%
d.iat[36,0]
df.iat[25,0]
#dr['Borough']=pandas.DataFrame(dr)
d['Borough']=pandas.DataFrame(dr)

# %%
f=df['Borough'].groupby(df['Postcode']).agg(lambda x: ','.join(x.values)).reset_index()
f=pandas.DataFrame(f)
d= d[[ 'Postcode','Borough', 'Neighbourhood']]
d
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
d.shape
# Out:
# (103, 3)

# %%
from IPython.display import Markdown,display
display(Markdown("__Getting the Geospatial data.__"))
geo_data = pandas.read_csv("http://cocl.us/Geospatial_data")
display(Markdown("__Renaming the columns to merge .__"))
geo_data = geo_data.rename(columns={"Postal Code":"Postcode"})
# Out:
# __Getting the Geospatial data.__
# __Renaming the columns to merge .__

# %%
d = d.merge(geo_data,on=['Postcode'])

# %%
display(Markdown("__Dataframe with Coordinates of respective postal codes.__"))
d
# Out:
# __Dataframe with Coordinates of respective postal codes.__
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# ...

# %%
display(Markdown("__Getting the coordinates of torento from geopy geocoders library.__"))
from geopy.geocoders import Nominatim
# import folium
address = 'Toronto'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Torento  are {}, {}.'.format(latitude, longitude))
# Out:
# __Getting the coordinates of torento from geopy geocoders library.__
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-808-f2c07c44b150> in <module>
#       1 display(Markdown("__Getting the coordinates of torento from geopy geocoders library.__"))
# ----> 2 from geopy.geocoders import Nominatim
#       3 # import folium
#       4 address = 'Toronto'
#       5
#
# ModuleNotFoundError: No module named 'geopy'
